# %% [markdown]
# # Simples tests on Iris datasets
# This is a small notebook presenting Perceptron, SGD Classifier, Logistic Regression and SVC applied on the Iris dataset.

# %%
"""
This function takes a model as first argument, train it on iris dataset and displays its result.
"""
def show(clf):

    # Imports
    from sklearn import datasets
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import accuracy_score
    from mlxtend.plotting import plot_decision_regions
    import matplotlib.pyplot as plt

    # Make datasets
    iris = datasets.load_iris()
    X = iris.data[:, 0:2]
    y = iris.target
    Xtr, Xte, ytr, yte = train_test_split(X, y, test_size=0.3)

    # Train classifier
    clf.fit(Xtr, ytr)
    print('Accuracy: %.2f' % accuracy_score(yte, clf.predict(Xte)))

    # Plot decision regions
    plot_decision_regions(X, y, clf=clf, legend=2)
    plt.xlabel('sepal length [cm]')
    plt.ylabel('petal length [cm]')
    plt.show()

# %% [markdown]
# ## Perceptron

# %%
from sklearn.linear_model import Perceptron
show(Perceptron(tol=1e-3, random_state=0))
# Out:
# Accuracy: 0.73

# %% [markdown]
# ## SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier
show(SGDClassifier(max_iter=1000, tol=1e-3))
# Out:
# Accuracy: 0.78

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
show(LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial'))
# Out:
# Accuracy: 0.82

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC
show(SVC(C=0.5, kernel='linear'))
# Out:
# Accuracy: 0.80
